# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\SYED  MOHAMMED GHOUS\Downloads\Messy_Employee_dataset.csv')
df
# Out:
#      Employee_ID First_Name Last_Name   Age   Department_Region    Status  \
# 0        EMP1000        Bob     Davis  25.0   DevOps-California    Active
# 1        EMP1001        Bob     Brown   NaN       Finance-Texas    Active
# 2        EMP1002      Alice     Jones   NaN        Admin-Nevada   Pending
# 3        EMP1003        Eva     Davis  25.0        Admin-Nevada  Inactive
# 4        EMP1004      Frank  Williams  25.0  Cloud Tech-Florida    Active
# ...          ...        ...       ...   ...                 ...       ...
# 1015     EMP2015      David    Miller  30.0       HR-California    Active
# 1016     EMP2016      David   Johnson  30.0    Cloud Tech-Texas  Inactive
# 1017     EMP2017    Charlie  Williams  40.0    Finance-New York    Active
# 1018     EMP2018      Alice    Garcia  30.0          HR-Florida  Inactive
# 1019     EMP2019      Heidi     Jones  30.0     DevOps-Illinois   Pending
#
#        Join_Date     Salary                         Email       Phone  \
# ...

# %%
df.shape
# Out:
# (1020, 12)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Employee_ID        1020 non-null   str
#  1   First_Name         1020 non-null   str
#  2   Last_Name          1020 non-null   str
#  3   Age                809 non-null    float64
#  4   Department_Region  1020 non-null   str
#  5   Status             1020 non-null   str
#  6   Join_Date          1020 non-null   str
#  7   Salary             996 non-null    float64
#  8   Email              1020 non-null   str
#  9   Phone              1020 non-null   int64
#  10  Performance_Score  1020 non-null   str
#  11  Remote_Work        1020 non-null   bool
# dtypes: bool(1), float64(2), int64(1), str(8)
# memory usage: 88.8 KB

# %%
df.isnull().sum()
# Out:
# Employee_ID            0
# First_Name             0
# Last_Name              0
# Age                  211
# Department_Region      0
# Status                 0
# Join_Date              0
# Salary                24
# Email                  0
# Phone                  0
# Performance_Score      0
# Remote_Work            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Employee_ID              str
# First_Name               str
# Last_Name                str
# Age                  float64
# Department_Region        str
# Status                   str
# Join_Date                str
# Salary               float64
# Email                    str
# Phone                  int64
# Performance_Score        str
# Remote_Work             bool
# dtype: object

# %%
df['Join_Date'].head(10)
# Out:
# 0    04-02-2021
# 1    07-10-2020
# 2    12-07-2023
# 3    11/27/2021
# 4    01-05-2022
# 5    06-10-2020
# 6    04-03-2020
# 7     7/17/2022
# 8    12-08-2023
# 9    08-04-2022
# Name: Join_Date, dtype: str

# %%
df['Join_Date'] = pd.to_datetime(df['Join_Date'], errors='coerce')

# %%
df['Join_Date'].dtype
# Out:
# dtype('<M8[us]')

# %%
df['Join_Date'].isnull().sum()
# Out:
# np.int64(620)

# %%
df['Phone'].head(10)
# Out:
# 0   -1651623197
# 1   -1898471390
# 2   -5596363211
# 3   -3476490784
# 4   -1586734256
# 5   -5409003485
# 6   -4518376063
# 7   -4134327559
# 8   -4177656123
# 9   -8156985699
# Name: Phone, dtype: int64

# %%
df['Phone'].tail(10)
# Out:
# 1010   -8307482072
# 1011   -6511893939
# 1012   -6557820189
# 1013   -4322302332
# 1014   -2470739200
# 1015   -3546212759
# 1016   -2508261122
# 1017   -1261632487
# 1018   -8995729892
# 1019   -7629745492
# Name: Phone, dtype: int64

# %%
df['Phone'].isnull().sum()
# Out:
# np.int64(0)

# %%
(df['Phone'] < 0).sum()
# Out:
# np.int64(1020)

# %%
df['Phone'].min(), df['Phone'].max()
# Out:
# (np.int64(-9994973202), np.int64(-3896086))

# %%
df['Phone'].abs().astype(str).str.len().value_counts()
# Out:
# Phone
# 10    928
# 9      78
# 8      12
# 7       2
# Name: count, dtype: int64

# %%
df[df['Phone'].abs().astype(str).str.len()<10]
# Out:
#      Employee_ID First_Name Last_Name   Age Department_Region    Status  \
# 43       EMP1043        Bob    Garcia   NaN  Admin-California  Inactive
# 45       EMP1045      Alice     Brown  25.0       HR-New York   Pending
# 47       EMP1047      Alice     Davis  35.0    Sales-Illinois    Active
# 58       EMP1058      David  Williams  35.0     Finance-Texas   Pending
# 68       EMP1068        Bob     Brown  40.0     Admin-Florida   Pending
# ...          ...        ...       ...   ...               ...       ...
# 946      EMP1946    Charlie     Jones  25.0    Admin-Illinois  Inactive
# 948      EMP1948        Bob    Miller  40.0     Finance-Texas    Active
# 986      EMP1986      Grace     Brown  30.0    Finance-Nevada    Active
# 1002     EMP2002        Bob     Smith  35.0  Finance-Illinois   Pending
# 1006     EMP2006      Grace     Brown   NaN       HR-Illinois  Inactive
#
#       Join_Date     Salary                       Email      Phone  \
# ...

# %%
df['Phone'].abs().astype(str).str.len().value_counts().sort_index()
# Out:
# Phone
# 7       2
# 8      12
# 9      78
# 10    928
# Name: count, dtype: int64

# %%
df['Phone'] = df['Phone'].abs()

# %%
df['Phone'] = df['Phone'].astype(str)

# %%
df['Phone'].head()
# Out:
# 0    1651623197
# 1    1898471390
# 2    5596363211
# 3    3476490784
# 4    1586734256
# Name: Phone, dtype: str

# %%
df['Phone'].astype(str)
# Out:
# 0       1651623197
# 1       1898471390
# 2       5596363211
# 3       3476490784
# 4       1586734256
#            ...
# 1015    3546212759
# 1016    2508261122
# 1017    1261632487
# 1018    8995729892
# 1019    7629745492
# Name: Phone, Length: 1020, dtype: str

# %%
df['Performance_Score'].value_counts()
# Out:
# Performance_Score
# Good         270
# Average      267
# Excellent    267
# Poor         216
# Name: count, dtype: int64

# %%
df['Performance_Score'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Status'].value_counts()
# Out:
# Status
# Pending     356
# Active      352
# Inactive    312
# Name: count, dtype: int64

# %%
df['Status'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Department_Region'].value_counts()
# Out:
# Department_Region
# HR-Florida               41
# DevOps-California        35
# Sales-Nevada             35
# Admin-Nevada             34
# Admin-California         34
# DevOps-Florida           34
# DevOps-New York          33
# HR-New York              33
# Sales-Florida            33
# DevOps-Illinois          33
# Finance-Illinois         33
# Finance-California       32
# Sales-California         31
# Sales-Illinois           30
# Finance-Texas            29
# Admin-Illinois           29
# Finance-Nevada           29
# Cloud Tech-Texas         29
# Cloud Tech-California    29
# Cloud Tech-Florida       28
# DevOps-Texas             27
# DevOps-Nevada            27
# Sales-New York           26
# HR-California            26
# Admin-Florida            25
# Cloud Tech-New York      24
# Finance-Florida          24
# HR-Nevada                24
# HR-Illinois              24
# Sales-Texas              23
# HR-Texas                 23
# Finance-New York         23
# ...

# %%
df['Department_Region'].str.split('-').str.len().value_counts()
# Out:
# Department_Region
# 2    1020
# Name: count, dtype: int64

# %%
df['Age'].describe()
# Out:
# count    809.000000
# mean      32.484549
# std        5.656860
# min       25.000000
# 25%       25.000000
# 50%       30.000000
# 75%       40.000000
# max       40.000000
# Name: Age, dtype: float64

# %%
df['Age'].value_counts().sort_index()
# Out:
# Age
# 25.0    206
# 30.0    205
# 35.0    188
# 40.0    210
# Name: count, dtype: int64

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())

# %%
df['Age'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Age'].describe()
# Out:
# count    1020.000000
# mean       31.970588
# std         5.136901
# min        25.000000
# 25%        30.000000
# 50%        30.000000
# 75%        35.000000
# max        40.000000
# Name: Age, dtype: float64

# %%
df['Age'].value_counts()
# Out:
# Age
# 30.0    416
# 40.0    210
# 25.0    206
# 35.0    188
# Name: count, dtype: int64

# %%
df['Salary'].describe()
# Out:
# count       996.000000
# mean      85155.056396
# std       19873.727918
# min       50047.320000
# 25%       68392.487500
# 50%       85547.870000
# 75%      100974.027500
# max      119971.650000
# Name: Salary, dtype: float64

# %%
df['Salary'].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 1020 entries, 0 to 1019
# Series name: Salary
# Non-Null Count  Dtype
# --------------  -----
# 996 non-null    float64
# dtypes: float64(1)
# memory usage: 8.1 KB

# %%
df['Salary'].value_counts().sort_index()
# Out:
# Salary
# 50047.32     1
# 50060.73     1
# 50110.66     1
# 50153.79     1
# 50173.12     1
#             ..
# 119586.11    1
# 119764.20    1
# 119801.30    1
# 119890.35    1
# 119971.65    1
# Name: count, Length: 978, dtype: int64

# %%
df['Salary'] = df['Salary'].fillna(df['Salary'].median())

# %%
df['Salary'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Email'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Email'].duplicated().sum()
# Out:
# np.int64(956)

# %%
df['Remote_Work'].value_counts()
# Out:
# Remote_Work
# True     513
# False    507
# Name: count, dtype: int64

# %%
df['Remote_Work'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Employee_ID'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Employee_ID'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df['First_Name'].isnull().sum()
df['Last_Name'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Phone_Length'] = df['Phone'].str.len()

# %%
df['Phone_Length'].value_counts().sort_index()
# Out:
# Phone_Length
# 7       2
# 8      12
# 9      78
# 10    928
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Employee_ID            0
# First_Name             0
# Last_Name              0
# Age                    0
# Department_Region      0
# Status                 0
# Join_Date            620
# Salary                 0
# Email                  0
# Phone                  0
# Performance_Score      0
# Remote_Work            0
# Phone_Length           0
# dtype: int64

# %%
df.drop('Phone_Length', axis=1, inplace=True)

# %%
df.shape
# Out:
# (1020, 12)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[['Department', 'Region']] = df['Department_Region'].str.split('-', expand=True)
df
# Out:
#      Employee_ID First_Name Last_Name   Age   Department_Region    Status  \
# 0        EMP1000        Bob     Davis  25.0   DevOps-California    Active
# 1        EMP1001        Bob     Brown  30.0       Finance-Texas    Active
# 2        EMP1002      Alice     Jones  30.0        Admin-Nevada   Pending
# 3        EMP1003        Eva     Davis  25.0        Admin-Nevada  Inactive
# 4        EMP1004      Frank  Williams  25.0  Cloud Tech-Florida    Active
# ...          ...        ...       ...   ...                 ...       ...
# 1015     EMP2015      David    Miller  30.0       HR-California    Active
# 1016     EMP2016      David   Johnson  30.0    Cloud Tech-Texas  Inactive
# 1017     EMP2017    Charlie  Williams  40.0    Finance-New York    Active
# 1018     EMP2018      Alice    Garcia  30.0          HR-Florida  Inactive
# 1019     EMP2019      Heidi     Jones  30.0     DevOps-Illinois   Pending
#
#       Join_Date     Salary                         Email       Phone  \
# ...

# %%
df['Department'].value_counts()
# Out:
# Department
# DevOps        189
# Sales         178
# HR            171
# Finance       170
# Admin         166
# Cloud Tech    146
# Name: count, dtype: int64

# %%
df['Region'].value_counts()
# Out:
# Region
# California    187
# Florida       185
# Nevada        169
# Illinois      165
# New York      161
# Texas         153
# Name: count, dtype: int64

# %%
df['Status'].value_counts()
# Out:
# Status
# Pending     356
# Active      352
# Inactive    312
# Name: count, dtype: int64

# %%
df['Performance_Score'].value_counts()
# Out:
# Performance_Score
# Good         270
# Average      267
# Excellent    267
# Poor         216
# Name: count, dtype: int64

# %%
df.groupby('Department')['Salary'].mean().sort_values(ascending=False)
# Out:
# Department
# Sales         86873.948258
# DevOps        86003.638624
# HR            85475.379474
# Admin         85202.644096
# Cloud Tech    84944.434658
# Finance       82279.519353
# Name: Salary, dtype: float64

# %%
df['Salary'].describe()
# Out:
# count      1020.000000
# mean      85164.299069
# std       19638.385740
# min       50047.320000
# 25%       68811.232500
# 50%       85547.870000
# 75%      100372.662500
# max      119971.650000
# Name: Salary, dtype: float64

# %%
df['Age'].describe()
# Out:
# count    1020.000000
# mean       31.970588
# std         5.136901
# min        25.000000
# 25%        30.000000
# 50%        30.000000
# 75%        35.000000
# max        40.000000
# Name: Age, dtype: float64

# %%
df[['Age', 'Salary']].corr()
# Out:
#              Age    Salary
# Age     1.000000  0.076761
# Salary  0.076761  1.000000

# %%
df.groupby('Remote_Work')['Salary'].mean().sort_values(ascending=False)
# Out:
# Remote_Work
# False    85835.187219
# True     84501.257563
# Name: Salary, dtype: float64

# %%
df.groupby('Status')['Salary'].mean().sort_values(ascending=False)
# Out:
# Status
# Pending     85733.620927
# Active      85139.967727
# Inactive    84542.138974
# Name: Salary, dtype: float64

# %%
df.groupby(['Department', 'Region'])['Salary'].mean().sort_values(ascending=False).head(10)
# Out:
# Department  Region
# Admin       Illinois      92050.898621
# Cloud Tech  Florida       91715.487857
# Sales       Florida       90582.736667
# DevOps      Nevada        90001.822593
# Admin       California    89564.108824
# Finance     New York      89159.340435
# Sales       California    88533.919677
# HR          Texas         88007.280870
#             California    87745.022692
#             Illinois      87707.819167
# Name: Salary, dtype: float64

# %%
df.groupby(['Department', 'Region'])['Salary'].mean().sort_values(ascending=False).tail(10)
# Out:
# Department  Region
# Finance     Texas         83832.979310
#             Florida       83098.247917
# DevOps      California    82772.097143
# Admin       Texas         81871.540000
#             Nevada        80641.359412
# HR          Florida       80460.818293
# Admin       New York      78822.267727
# Cloud Tech  New York      78086.093333
# Finance     Nevada        76398.523448
#             Illinois      75707.702424
# Name: Salary, dtype: float64

# %%
df
# Out:
#      Employee_ID First_Name Last_Name   Age   Department_Region    Status  \
# 0        EMP1000        Bob     Davis  25.0   DevOps-California    Active
# 1        EMP1001        Bob     Brown  30.0       Finance-Texas    Active
# 2        EMP1002      Alice     Jones  30.0        Admin-Nevada   Pending
# 3        EMP1003        Eva     Davis  25.0        Admin-Nevada  Inactive
# 4        EMP1004      Frank  Williams  25.0  Cloud Tech-Florida    Active
# ...          ...        ...       ...   ...                 ...       ...
# 1015     EMP2015      David    Miller  30.0       HR-California    Active
# 1016     EMP2016      David   Johnson  30.0    Cloud Tech-Texas  Inactive
# 1017     EMP2017    Charlie  Williams  40.0    Finance-New York    Active
# 1018     EMP2018      Alice    Garcia  30.0          HR-Florida  Inactive
# 1019     EMP2019      Heidi     Jones  30.0     DevOps-Illinois   Pending
#
#       Join_Date     Salary                         Email       Phone  \
# ...

# %%
df.isna().sum()
# Out:
# Employee_ID            0
# First_Name             0
# Last_Name              0
# Age                    0
# Department_Region      0
# Status                 0
# Join_Date            620
# Salary                 0
# Email                  0
# Phone                  0
# Performance_Score      0
# Remote_Work            0
# Department             0
# Region                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Employee_ID                     str
# First_Name                      str
# Last_Name                       str
# Age                         float64
# Department_Region               str
# Status                          str
# Join_Date            datetime64[us]
# Salary                      float64
# Email                           str
# Phone                           str
# Performance_Score               str
# Remote_Work                    bool
# Department                      str
# Region                          str
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Phone'].head(5)
# Out:
# 0    1651623197
# 1    1898471390
# 2    5596363211
# 3    3476490784
# 4    1586734256
# Name: Phone, dtype: str

# %%
df = df.drop(columns=['Department_Region'])

# %%
df['Status'].unique()
df['Performance_Score'].unique()
df['Remote_Work'].unique()
# Out:
# array([ True, False])

# %%
df['Status'].unique()
df['Performance_Score'].unique()
# Out:
# <StringArray>
# ['Average', 'Excellent', 'Good', 'Poor']
# Length: 4, dtype: str

# %%
df['Performance_Score'].unique()
# Out:
# <StringArray>
# ['Average', 'Excellent', 'Good', 'Poor']
# Length: 4, dtype: str

# %%
df['Status'].unique()
# Out:
# <StringArray>
# ['Active', 'Pending', 'Inactive']
# Length: 3, dtype: str

# %%
Q1 = df['Salary'].quantile(0.25)
Q3 = df['Salary'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR
outliers = df[(df['Salary'] < lower) | (df['Salary'] > upper)]
print(f"Lower bound: {lower}, Upper bound: {upper}")
print(f"Number of outliers: {len(outliers)}")Q1 = df['Salary'].quantile(0.25)
Q3 = df['Salary'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR
outliers = df[(df['Salary'] < lower) | (df['Salary'] > upper)]
print(f"Lower bound: {lower}, Upper bound: {upper}")
print(f"Number of outliers: {len(outliers)}")
# Out:
#   Cell In[87], line 8
#     print(f"Number of outliers: {len(outliers)}")Q1 = df['Salary'].quantile(0.25)
#                                                  ^
# SyntaxError: invalid syntax

# %%
Q1 = df['Salary'].quantile(0.25)
Q3 = df['Salary'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR
outliers = df[(df['Salary'] < lower) | (df['Salary'] > upper)]
print(f"Lower bound: {lower}, Upper bound: {upper}")
print(f"Number of outliers: {len(outliers)}")
# Out:
# Lower bound: 21469.087499999987, Upper bound: 147714.80750000002
# Number of outliers: 0

# %%
Q1 = df['Age'].quantile(0.25)
Q3 = df['Age'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR
outliers = df[(df['Age'] < lower) | (df['Age'] > upper)]
print(f"Lower bound: {lower}, Upper bound: {upper}")
print(f"Number of outliers: {len(outliers)}")
# Out:
# Lower bound: 22.5, Upper bound: 42.5
# Number of outliers: 0

# %%
df.to_csv(r'C:\Users\SYED  MOHAMMED GHOUS\Downloads\Messy_Employee_dataset_cleaned.csv', index=False)

# %% [markdown]
# ## Data Cleaning Summary — Before vs. After
#
# | Metric | Before Cleaning | After Cleaning |
# |---|---|---|
# | Total rows | 1,020 | 1,020 |
# | Total columns | 12 | 13 (Department_Region split into Department + Region) |
# | Missing values — Age | 211 | 0 (filled with median) |
# | Missing values — Salary | 24 | 0 (filled with median) |
# | Duplicate rows | 0 | 0 |
# | Join_Date dtype | object (string) | datetime64 |
# | Phone dtype | int64 (negative values) | string |
# | Salary outliers (IQR method) | Not checked | 0 found |
# | Age outliers (IQR method) | Not checked | 0 found |
# | Category formatting (Status, Performance_Score) | Unchecked | Verified clean — no inconsistencies |
